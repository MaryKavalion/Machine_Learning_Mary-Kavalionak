# %%
import numpy as np
import seaborn as sns
sns.set_style("darkgrid")

# %% [markdown]
# ### ex. 0: Simulate phone dataset

# %% [markdown]
# part A

# %%
np.random.seed(42)
minutes_month = np.random.normal(loc = 100, scale = 100, size = 400)
minutes_month = [np.abs(i) for i in minutes_month]
noise_values = np.random.normal(loc = 0, scale = 50, size = 400)

cost_per_month = [(2*minutes_month[i] + 25 + noise_values[i]) for i in range (len(minutes_month))]
cost_per_month

# %% [markdown]
# * Установка "seed" в 42 означает установку начального значения (seed) для генератора случайных чисел равным 42.

# %%
sns.regplot (x = minutes_month, y = cost_per_month)
# Out:
# <Axes: >

# %% [markdown]
# part B

# %% [markdown]
# Переделать (написать функцию? почистить х, пересоздать у)

# %%
cost_per_month_cleaned = [(2*minutes_month[i] + 25 + noise_values[i]) for i in range (len(minutes_month)) 
                          if (minutes_month[i] <= 300 and ((minutes_month[i] + 25 + noise_values [i]) >= 0))]
len (cost_per_month_cleaned)
# Out:
# 372
